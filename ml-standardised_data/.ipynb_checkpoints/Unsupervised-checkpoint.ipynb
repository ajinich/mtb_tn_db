# %%
import pandas as pd
import os

# %%
lfc = pd.read_csv('../data/standardized_data/result_logfc_matrix_2019_12_10.csv')

# %%
lfc.head()
# Out:
#     Rv_ID  PE35_KO_vs_mbio_H37Rv  PPE68_KO_vs_mbio_H37Rv  Rv0950c_KO_vs_CB_WT  \
# 0  Rv0001                  -0.41                    0.01                 0.00
# 1  Rv0002                   3.28                    2.38                 0.00
# 2  Rv0003                  -0.03                   -0.08                 0.03
# 3  Rv0004                  -3.81                   -3.39                -2.60
# 4  Rv0005                  -0.22                    0.14                 0.13
#
#    Rv0954_KO_vs_RJ_WT  Rv1096_KO_vs_CB_WT  \
# 0                0.00                0.00
# 1                0.00                0.00
# 2               -1.20                0.39
# 3               -6.83                1.54
# 4               -0.08                0.27
#
#    Rv3005c_KO_day32_vs_dejesus_H37Rv_day32  Rv3594_KO_vs_Rubin_FLUTE_WT  \
# 0                                     3.12                        -0.06
# 1                                     0.00                         0.00
# 2                                     3.83                         0.31
# 3                                     0.00                         1.79
# 4                                    -2.38                         0.70
#
#    Rv3684_KO_vs_CB_WT  Rv3717_KO_vs_Rubin_FLUTE_WT  ...  \
# 0                0.00                        -0.06  ...
# 1                0.00                         0.00  ...
# 2                0.17                        -0.62  ...
# 3                1.08                         4.91  ...
# 4               -0.71                        -0.37  ...
#
#    zhang_AA_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                              0.00
# 1                                              0.00
# 2                                             -2.93
# 3                                             -3.56
# 4                                             -1.47
#
#    zhang_DETA-NO_pH_7.0_vs_zhang_pH_7.0_no_NO_control  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -0.31
# 3                                               0.00
# 4                                              -0.89
#
#    zhang_Fe_1.5mM_vs_zhang_Fe_450uM  \
# 0                              0.00
# 1                              0.00
# 2                              1.09
# 3                              1.96
# 4                             -2.36
#
#    zhang_Trp_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -2.13
# 3                                              -3.56
# 4                                              -1.89
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_Tyloxapol_pH_4.5  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.51
# 3                                              0.00
# 4                                              2.90
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  \
# 0                                         0.00
# 1                                         0.00
# 2                                         0.41
# 3                                         0.00
# 4                                         2.20
#
#    zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10  \
# 0                                         0.00
# 1                                         0.00
# 2                                         1.30
# 3                                         0.00
# 4                                        -4.05
#
#    zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  \
# 0                                         0.00
# 1                                         0.00
# 2                                        -0.49
# 3                                         0.70
# 4                                         0.30
#
#    zhang_wt_mouse_d10_vs_zhang_input_library  \
# 0                                       0.00
# 1                                       0.00
# 2                                      -1.26
# 3                                      -2.62
# 4                                       0.69
#
#    zhang_wt_mouse_d45_vs_zhang_input_library
# 0                                       0.00
# 1                                       0.00
# 2                                      -2.25
# 3                                      -2.62
# 4                                      -3.55
#
# [5 rows x 65 columns]

# %%
lfc=lfc.dropna(axis=0)

# %%
mbio = pd.read_excel("../data/annotations/DeJesus_mbio.xlsx", header=1)
mbio.head()
# Out:
#    ORF ID  Name                                        Description  \
# 0  Rv0001  dnaA     Chromosomal replication initiator protein DnaA
# 1  Rv0002  dnaN  DNA polymerase III (beta chain) DnaN (DNA nucl...
# 2  Rv0003  recF  DNA replication and repair protein RecF (singl...
# 3  Rv0004     -                               hypothetical protein
# 4  Rv0005  gyrB  DNA gyrase (subunit B) GyrB (DNA topoisomerase...
#
#    Number of TA Sites  Number of Permissive (P) Sites  \
# 0                  32                              29
# 1                  31                              27
# 2                  35                              32
# 3                   8                               8
# 4                  40                              36
#
#    Number of Non-Permissive (NP) Sites  \
# 0                                    3
# 1                                    4
# 2                                    3
# 3                                    0
# 4                                    4
#
#    Number of Sites Belonging to Essential State  \
# 0                                            31
# 1                                            31
# 2                                             0
# 3                                             0
# 4                                            39
#
#    Number of Sites Belonging to Growth-Defect State  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#    Number of Sites Belonging to Non-Essential State  \
# 0                                                 1
# 1                                                 0
# 2                                                35
# 3                                                 8
# 4                                                 1
#
#    Number of Sites Belonging to Growth-Advantage State  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Fraction of Sites with Insertions  \
# 0                           0.125000
# 1                           0.032258
# 2                           0.857143
# 3                           0.375000
# 4                           0.025000
#
#    Mean Normalized Read-Count At Non-Zero Sites Final Call
# 0                                     45.000000         ES
# 1                                      1.000000         ES
# 2                                     38.033333         NE
# 3                                    144.000000         NE
# 4                                     26.000000         ES

# %%
print(lfc.shape)
lfc=pd.merge(lfc, mbio[['ORF ID', 'Name', 'Description', 'Final Call']], how='left', left_on='Rv_ID', right_on='ORF ID')
print(lfc.shape)
# Out:
# (3971, 65)
# (3971, 69)

# %%
mcbwser = pd.read_excel("../data/annotations/Mycobacterium_tuberculosis_H37Rv_txt_v3.xlsx")
mcbwser.head()
# Out:
#      Refseq_ID Feature    Rv_ID     Name  \
# 0  NC_000962.3     CDS   Rv3728   Rv3728
# 1  NC_000962.3     CDS   Rv3729   Rv3729
# 2  NC_000962.3     CDS  Rv3730c  Rv3730c
# 3  NC_000962.3     CDS   Rv3760   Rv3760
# 4  NC_000962.3     CDS   Rv3732   Rv3732
#
#                                             Function  \
# 0  Unknown, but seems involved in efflux system (...
# 1  Function unknown; probably involved in cellula...
# 2                                   Function unknown
# 3                                            Unknown
# 4                                   Function unknown
#
#                                           Product  \
# 0  Probable conserved two-domain membrane protein
# 1                            Possible transferase
# 2                  Conserved hypothetical protein
# 3             Possible conserved membrane protein
# 4                               Conserved protein
#
#                                             Comments  \
# 0  Rv3728, (MTV025.076), len: 1065 aa. Probable c...
# 1  Rv3729, (MTV025.077), len: 776 aa. Conserved h...
# 2  Rv3730c, (MTV025.078c), len: 346 aa. Conserved...
# 3  Rv3760, (MTV025.108), len: 100 aa. Possible co...
# 4  Rv3732, (MTV025.080), len: 352 aa. Conserved p...
#
#                        Functional_Category
# 0             cell wall and cell processes
# 1  intermediary metabolism and respiration
# 2                  conserved hypotheticals
# 3             cell wall and cell processes
# 4                  conserved hypotheticals

# %%
mcbwser = mcbwser.drop_duplicates(subset=['Rv_ID'])

# %%
print(lfc.shape)
lfc=pd.merge(lfc, mcbwser[['Rv_ID', 'Functional_Category']], how='left', on='Rv_ID')
print(lfc.shape)
# Out:
# (3971, 69)
# (3971, 70)

# %%
lfc=lfc.drop(columns='ORF ID')

# %%
lfc.head()
# Out:
#     Rv_ID  PE35_KO_vs_mbio_H37Rv  PPE68_KO_vs_mbio_H37Rv  Rv0950c_KO_vs_CB_WT  \
# 0  Rv0001                  -0.41                    0.01                 0.00
# 1  Rv0002                   3.28                    2.38                 0.00
# 2  Rv0003                  -0.03                   -0.08                 0.03
# 3  Rv0004                  -3.81                   -3.39                -2.60
# 4  Rv0005                  -0.22                    0.14                 0.13
#
#    Rv0954_KO_vs_RJ_WT  Rv1096_KO_vs_CB_WT  \
# 0                0.00                0.00
# 1                0.00                0.00
# 2               -1.20                0.39
# 3               -6.83                1.54
# 4               -0.08                0.27
#
#    Rv3005c_KO_day32_vs_dejesus_H37Rv_day32  Rv3594_KO_vs_Rubin_FLUTE_WT  \
# 0                                     3.12                        -0.06
# 1                                     0.00                         0.00
# 2                                     3.83                         0.31
# 3                                     0.00                         1.79
# 4                                    -2.38                         0.70
#
#    Rv3684_KO_vs_CB_WT  Rv3717_KO_vs_Rubin_FLUTE_WT  ...  \
# 0                0.00                        -0.06  ...
# 1                0.00                         0.00  ...
# 2                0.17                        -0.62  ...
# 3                1.08                         4.91  ...
# 4               -0.71                        -0.37  ...
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_Tyloxapol_pH_4.5  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.51
# 3                                              0.00
# 4                                              2.90
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  \
# 0                                         0.00
# 1                                         0.00
# 2                                         0.41
# 3                                         0.00
# 4                                         2.20
#
#    zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10  \
# 0                                         0.00
# 1                                         0.00
# 2                                         1.30
# 3                                         0.00
# 4                                        -4.05
#
#    zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  \
# 0                                         0.00
# 1                                         0.00
# 2                                        -0.49
# 3                                         0.70
# 4                                         0.30
#
#    zhang_wt_mouse_d10_vs_zhang_input_library  \
# 0                                       0.00
# 1                                       0.00
# 2                                      -1.26
# 3                                      -2.62
# 4                                       0.69
#
#    zhang_wt_mouse_d45_vs_zhang_input_library  Name  \
# 0                                       0.00  dnaA
# 1                                       0.00  dnaN
# 2                                      -2.25  recF
# 3                                      -2.62     -
# 4                                      -3.55  gyrB
#
#                                          Description  Final Call  \
# 0     Chromosomal replication initiator protein DnaA          ES
# 1  DNA polymerase III (beta chain) DnaN (DNA nucl...          ES
# 2  DNA replication and repair protein RecF (singl...          NE
# 3                               hypothetical protein          NE
# 4  DNA gyrase (subunit B) GyrB (DNA topoisomerase...          ES
#
#        Functional_Category
# 0     information pathways
# 1     information pathways
# 2     information pathways
# 3  conserved hypotheticals
# 4     information pathways
#
# [5 rows x 69 columns]

# %%
desc_columns=['Rv_ID', 'Name', 'Description', 'Final Call', 'Functional_Category']
value_cols=[col for col in lfc.columns if col not in desc_columns]
lfc=lfc[desc_columns + value_cols]

# %%
lfc.head()
# Out:
#     Rv_ID  Name                                        Description Final Call  \
# 0  Rv0001  dnaA     Chromosomal replication initiator protein DnaA         ES
# 1  Rv0002  dnaN  DNA polymerase III (beta chain) DnaN (DNA nucl...         ES
# 2  Rv0003  recF  DNA replication and repair protein RecF (singl...         NE
# 3  Rv0004     -                               hypothetical protein         NE
# 4  Rv0005  gyrB  DNA gyrase (subunit B) GyrB (DNA topoisomerase...         ES
#
#        Functional_Category  PE35_KO_vs_mbio_H37Rv  PPE68_KO_vs_mbio_H37Rv  \
# 0     information pathways                  -0.41                    0.01
# 1     information pathways                   3.28                    2.38
# 2     information pathways                  -0.03                   -0.08
# 3  conserved hypotheticals                  -3.81                   -3.39
# 4     information pathways                  -0.22                    0.14
#
#    Rv0950c_KO_vs_CB_WT  Rv0954_KO_vs_RJ_WT  Rv1096_KO_vs_CB_WT  ...  \
# 0                 0.00                0.00                0.00  ...
# 1                 0.00                0.00                0.00  ...
# 2                 0.03               -1.20                0.39  ...
# 3                -2.60               -6.83                1.54  ...
# 4                 0.13               -0.08                0.27  ...
#
#    zhang_AA_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                              0.00
# 1                                              0.00
# 2                                             -2.93
# 3                                             -3.56
# 4                                             -1.47
#
#    zhang_DETA-NO_pH_7.0_vs_zhang_pH_7.0_no_NO_control  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -0.31
# 3                                               0.00
# 4                                              -0.89
#
#    zhang_Fe_1.5mM_vs_zhang_Fe_450uM  \
# 0                              0.00
# 1                              0.00
# 2                              1.09
# 3                              1.96
# 4                             -2.36
#
#    zhang_Trp_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -2.13
# 3                                              -3.56
# 4                                              -1.89
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_Tyloxapol_pH_4.5  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.51
# 3                                              0.00
# 4                                              2.90
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  \
# 0                                         0.00
# 1                                         0.00
# 2                                         0.41
# 3                                         0.00
# 4                                         2.20
#
#    zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10  \
# 0                                         0.00
# 1                                         0.00
# 2                                         1.30
# 3                                         0.00
# 4                                        -4.05
#
#    zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  \
# 0                                         0.00
# 1                                         0.00
# 2                                        -0.49
# 3                                         0.70
# 4                                         0.30
#
#    zhang_wt_mouse_d10_vs_zhang_input_library  \
# 0                                       0.00
# 1                                       0.00
# 2                                      -1.26
# 3                                      -2.62
# 4                                       0.69
#
#    zhang_wt_mouse_d45_vs_zhang_input_library
# 0                                       0.00
# 1                                       0.00
# 2                                      -2.25
# 3                                      -2.62
# 4                                      -3.55
#
# [5 rows x 69 columns]

# %%
from sklearn.decomposition import PCA
from plotnine import *

# %%
pca=PCA(3)
pca_results=pca.fit_transform(lfc[value_cols])
explained_var = pca.explained_variance_
pca_df=pd.DataFrame(pca_results, columns=['pca1', 'pca2', 'pca3'])

# %%
lfc=lfc.merge(pca_df, left_index=True, right_index=True)

# %%
(ggplot(lfc, aes(x='pca1', y='pca2', color='Final Call')) + geom_point() +
 theme_light() + xlab(f'pca1 {np.round(explained_var[0], 2)}') +
 ylab(f'pca2 {np.round(explained_var[1], 2)}'))
# Out:
# <ggplot: (-9223371924460800673)>

# %%
(ggplot(lfc, aes(x='pca1', y='pca2', color='Functional_Category'))
 +geom_point()
 +theme_light()
 +xlab(f'pca1 {np.round(explained_var[0], 2)}')
 +ylab(f'pca2 {np.round(explained_var[1], 2)}'))
# Out:
# <ggplot: (112393869814)>

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2).fit_transform(lfc[value_cols])

# %%
tsne = pd.DataFrame(tsne, columns=['tsne1', 'tsne2'])

# %%
lfc=lfc.merge(tsne, left_index=True, right_index=True)

# %%
(ggplot(lfc, aes(x='tsne1', y='tsne2', color='Final Call'))+geom_point()+theme_light())
# Out:
# <ggplot: (-9223371924465246527)>

# %%
(ggplot(lfc, aes(x='tsne1', y='tsne2', color='Functional_Category'))+geom_point()+theme_light())
# Out:
# <ggplot: (112392792240)>

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(lfc[value_cols], method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering 
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage ='ward')
y_hc=hc.fit_predict(lfc[value_cols])

# %%
lfc['y_hc']=y_hc

# %%
lfc
# Out:
#         Rv_ID  Name                                        Description  \
# 0      Rv0001  dnaA     Chromosomal replication initiator protein DnaA
# 1      Rv0002  dnaN  DNA polymerase III (beta chain) DnaN (DNA nucl...
# 2      Rv0003  recF  DNA replication and repair protein RecF (singl...
# 3      Rv0004     -                               hypothetical protein
# 4      Rv0005  gyrB  DNA gyrase (subunit B) GyrB (DNA topoisomerase...
# ...       ...   ...                                                ...
# 3966  Rv3920c     -           Conserved protein similar to jag protein
# 3967  Rv3921c     -           Probable conserved transmembrane protein
# 3968  Rv3922c     -                                 Possible hemolysin
# 3969  Rv3923c  rnpA  Ribonuclease P protein component RnpA (RNaseP ...
# 3970  Rv3924c  rpmH                     50S ribosomal protein L34 RpmH
#
#      Final Call                    Functional_Category  PE35_KO_vs_mbio_H37Rv  \
# 0            ES                   information pathways                  -0.41
# 1            ES                   information pathways                   3.28
# 2            NE                   information pathways                  -0.03
# 3            NE                conserved hypotheticals                  -3.81
# 4            ES                   information pathways                  -0.22
# ...         ...                                    ...                    ...
# 3966         NE                conserved hypotheticals                   0.06
# 3967        ESD           cell wall and cell processes                   1.98
# 3968         NE  virulence, detoxification, adaptation                  -0.88
# 3969         NE                   information pathways                  -0.32
# 3970  Uncertain                   information pathways                   0.00
#
#       PPE68_KO_vs_mbio_H37Rv  Rv0950c_KO_vs_CB_WT  Rv0954_KO_vs_RJ_WT  \
# 0                       0.01                 0.00                0.00
# 1                       2.38                 0.00                0.00
# 2                      -0.08                 0.03               -1.20
# 3                      -3.39                -2.60               -6.83
# 4                       0.14                 0.13               -0.08
# ...                      ...                  ...                 ...
# 3966                    0.00                 0.26               -1.73
# 3967                    1.92                 0.25                0.16
# 3968                   -0.37                -0.12               -0.82
# 3969                    0.10                -1.75                3.01
# 3970                    0.00                 0.00                0.00
#
#       Rv1096_KO_vs_CB_WT  ...    pca3_x    pca1_y     pca2_y    pca3_y  \
# 0                   0.00  ... -0.178064 -3.073950   1.063855 -0.177810
# 1                   0.00  ... -1.225848 -1.131512   0.284337 -1.225997
# 2                   0.39  ...  2.922614 -5.194010  -2.682658  2.923119
# 3                   1.54  ...  2.870962  2.211080 -16.763557  2.873338
# 4                   0.27  ...  5.810310  8.101300  -3.735075  5.809192
# ...                  ...  ...       ...       ...        ...       ...
# 3966               -0.05  ...  7.820788 -5.784319   1.667243  7.822504
# 3967                0.87  ... -0.478993 -1.487345   1.536544 -0.479863
# 3968                0.47  ...  0.543579 -5.765586  -4.743001  0.547910
# 3969                0.28  ...  6.326683 -0.481986  -4.027906  6.324546
# 3970                0.00  ... -1.137974 -0.974749  -0.152042 -1.137950
#
#           pca1       pca2      pca3      tsne1      tsne2  y_hc
# 0    -3.073951   1.063855 -0.177934 -32.743317  32.544189     3
# 1    -1.131511   0.284326 -1.225856 -23.473013  22.693598     3
# 2    -5.194012  -2.682636  2.922597  18.592005  24.938044     0
# 3     2.211073 -16.763460  2.871010 -42.457920   3.019264     0
# 4     8.101302  -3.735120  5.809935   8.394895 -58.664219     0
# ...        ...        ...       ...        ...        ...   ...
# 3966 -5.784324   1.667350  7.820096  18.277412   9.458494     0
# 3967 -1.487342   1.536518 -0.479199 -25.394161  22.298235     3
# 3968 -5.765595  -4.742882  0.544127  11.847923  21.036158     0
# 3969 -0.481985  -4.027945  6.326393 -41.472229  15.342778     0
# 3970 -0.974749  -0.152043 -1.137956 -11.757349  13.644540     3
#
# [3971 rows x 81 columns]

# %%
(ggplot(lfc, aes(x='factor(y_hc)'))+geom_bar(aes(fill='Final Call'), position='fill')+theme_light()+ylab('Fractional Count'))
# Out:
# C:\Users\light\Anaconda3\lib\site-packages\plotnine\stats\stat.py:311: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   stats = pd.concat(stats, axis=0, ignore_index=True)
# <ggplot: (-9223371924456818407)>

# %%
(ggplot(lfc, aes(x='factor(y_hc)'))+geom_bar(aes(fill='Functional_Category'), position='fill')+theme_light()+ylab('Fractional Count'))
# Out:
# <ggplot: (112399919147)>
