# %%
import pandas as pd
import numpy as np
import os

# %%
lfc = pd.read_csv('../data/standardized_data/result_logfc_matrix_2020_08_27.csv')

# %%
lfc.head()
# Out:
#     Rv_ID  PE35_KO_vs_mbio_H37Rv  PPE68_KO_vs_mbio_H37Rv  Rv0950c_KO_vs_CB_WT  \
# 0  Rv0001                  -0.41                    0.01                 0.00
# 1  Rv0002                   3.28                    2.38                 0.00
# 2  Rv0003                  -0.03                   -0.08                 0.03
# 3  Rv0004                  -3.81                   -3.39                -2.60
# 4  Rv0005                  -0.22                    0.14                 0.13
#
#    Rv0954_KO_vs_RJ_WT  Rv1096_KO_vs_CB_WT  \
# 0                0.00                0.00
# 1                0.00                0.00
# 2               -1.20                0.39
# 3               -6.83                1.54
# 4               -0.08                0.27
#
#    Rv3005c_KO_day32_vs_dejesus_H37Rv_day32  Rv3594_KO_vs_Rubin_FLUTE_WT  \
# 0                                     3.12                        -0.06
# 1                                     0.00                         0.00
# 2                                     3.83                         0.31
# 3                                     0.00                         1.79
# 4                                    -2.38                         0.70
#
#    Rv3684_KO_vs_CB_WT  Rv3717_KO_vs_Rubin_FLUTE_WT  ...  \
# 0                0.00                        -0.06  ...
# 1                0.00                         0.00  ...
# 2                0.17                        -0.62  ...
# 3                1.08                         4.91  ...
# 4               -0.71                        -0.37  ...
#
#    zhang_AA_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                              0.00
# 1                                              0.00
# 2                                             -2.93
# 3                                             -3.56
# 4                                             -1.47
#
#    zhang_DETA-NO_pH_7.0_vs_zhang_pH_7.0_no_NO_control  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -0.31
# 3                                               0.00
# 4                                              -0.89
#
#    zhang_Fe_1.5mM_vs_zhang_Fe_450uM  \
# 0                              0.00
# 1                              0.00
# 2                              1.09
# 3                              1.96
# 4                             -2.36
#
#    zhang_Trp_Rescue_vs_zhang_in_vitro_control_Rescue  \
# 0                                               0.00
# 1                                               0.00
# 2                                              -2.13
# 3                                              -3.56
# 4                                              -1.89
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_Tyloxapol_pH_4.5  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.51
# 3                                              0.00
# 4                                              2.90
#
#    zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  \
# 0                                         0.00
# 1                                         0.00
# 2                                         0.41
# 3                                         0.00
# 4                                         2.20
#
#    zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10  \
# 0                                         0.00
# 1                                         0.00
# 2                                         1.30
# 3                                         0.00
# 4                                        -4.05
#
#    zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  \
# 0                                         0.00
# 1                                         0.00
# 2                                        -0.49
# 3                                         0.70
# 4                                         0.30
#
#    zhang_wt_mouse_d10_vs_zhang_input_library  \
# 0                                       0.00
# 1                                       0.00
# 2                                      -1.26
# 3                                      -2.62
# 4                                       0.69
#
#    zhang_wt_mouse_d45_vs_zhang_input_library
# 0                                       0.00
# 1                                       0.00
# 2                                      -2.25
# 3                                      -2.62
# 4                                      -3.55
#
# [5 rows x 65 columns]

# %%
## REMOVE ESSENTIALS!
mbio = pd.read_excel("../data/annotations/DeJesus_mbio.xlsx", header=1)
mbio.head()
# Out:
#    ORF ID  Name                                        Description  \
# 0  Rv0001  dnaA     Chromosomal replication initiator protein DnaA
# 1  Rv0002  dnaN  DNA polymerase III (beta chain) DnaN (DNA nucl...
# 2  Rv0003  recF  DNA replication and repair protein RecF (singl...
# 3  Rv0004     -                               hypothetical protein
# 4  Rv0005  gyrB  DNA gyrase (subunit B) GyrB (DNA topoisomerase...
#
#    Number of TA Sites  Number of Permissive (P) Sites  \
# 0                  32                              29
# 1                  31                              27
# 2                  35                              32
# 3                   8                               8
# 4                  40                              36
#
#    Number of Non-Permissive (NP) Sites  \
# 0                                    3
# 1                                    4
# 2                                    3
# 3                                    0
# 4                                    4
#
#    Number of Sites Belonging to Essential State  \
# 0                                            31
# 1                                            31
# 2                                             0
# 3                                             0
# 4                                            39
#
#    Number of Sites Belonging to Growth-Defect State  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#    Number of Sites Belonging to Non-Essential State  \
# 0                                                 1
# 1                                                 0
# 2                                                35
# 3                                                 8
# 4                                                 1
#
#    Number of Sites Belonging to Growth-Advantage State  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Fraction of Sites with Insertions  \
# 0                           0.125000
# 1                           0.032258
# 2                           0.857143
# 3                           0.375000
# 4                           0.025000
#
#    Mean Normalized Read-Count At Non-Zero Sites Final Call
# 0                                     45.000000         ES
# 1                                      1.000000         ES
# 2                                     38.033333         NE
# 3                                    144.000000         NE
# 4                                     26.000000         ES

# %%
print(lfc.shape)
lfc = pd.merge(lfc, mbio[['ORF ID', 'Final Call']], how='left', left_on='Rv_ID', right_on='ORF ID')
print(lfc.shape)
# Out:
# (4055, 65)
# (4055, 67)

# %%
lfc = lfc[lfc['Final Call'] != 'ES']
lfc = lfc.drop(columns = ['ORF ID', 'Final Call'])
print(lfc.shape)
# Out:
# (3594, 65)

# %%
lfc=lfc.dropna(axis=0)
lfc=lfc.T.reset_index()
lfc.columns=list(lfc.iloc[0,:])
lfc=lfc.iloc[1:,:]
lfc=lfc.rename(columns={'Rv_ID': 'Dataset'})
lfc=lfc.set_index('Dataset')

# %%
lfc.head()
# Out:
#                        Rv0003 Rv0004 Rv0007 Rv0008c Rv0009 Rv0010c Rv0011c  \
# Dataset
# PE35_KO_vs_mbio_H37Rv   -0.03  -3.81  -0.44   -0.22  -0.13   -0.06    0.42
# PPE68_KO_vs_mbio_H37Rv  -0.08  -3.39  -0.14      -0  -0.12    0.07    0.56
# Rv0950c_KO_vs_CB_WT      0.03   -2.6  -0.47    0.43   -0.1    0.29    -1.6
# Rv0954_KO_vs_RJ_WT       -1.2  -6.83  -1.21   -0.51   0.78    0.31   -6.75
# Rv1096_KO_vs_CB_WT       0.39   1.54  -0.34    0.58   0.11    0.26   -1.98
#
#                        Rv0012 Rv0016c Rv0017c  ... Rv3911 Rv3912 Rv3914  \
# Dataset                                        ...
# PE35_KO_vs_mbio_H37Rv   -0.24    0.09   -0.12  ...  -0.18   0.26   0.11
# PPE68_KO_vs_mbio_H37Rv  -0.74   -0.25   -0.19  ...   0.07   0.31   0.53
# Rv0950c_KO_vs_CB_WT      0.29   -0.96   -0.65  ...   -0.3    0.1    0.7
# Rv0954_KO_vs_RJ_WT      -1.12   -4.57   -3.85  ...  -0.38   0.36  -2.05
# Rv1096_KO_vs_CB_WT      -1.12   -0.84   -0.38  ...  -0.17   0.12   1.55
#
#                        Rv3916c Rv3919c Rv3920c Rv3921c Rv3922c Rv3923c Rv3924c
# Dataset
# PE35_KO_vs_mbio_H37Rv     0.55    0.01    0.06    1.98   -0.88   -0.32       0
# PPE68_KO_vs_mbio_H37Rv    1.11    0.29       0    1.92   -0.37     0.1       0
# Rv0950c_KO_vs_CB_WT      -0.15    0.63    0.26    0.25   -0.12   -1.75       0
# Rv0954_KO_vs_RJ_WT        3.06   -1.56   -1.73    0.16   -0.82    3.01       0
# Rv1096_KO_vs_CB_WT       -0.27    0.52   -0.05    0.87    0.47    0.28       0
#
# [5 rows x 3511 columns]

# %%
value_cols=[col for col in lfc.columns if col!='Dataset']

# %%
from sklearn.decomposition import PCA
from plotnine import *

# %%
pca=PCA(3)
pca_results=pca.fit_transform(lfc[value_cols])
# print(pca_results)
explained_var = pca.explained_variance_ratio_
print(pca.explained_variance_ratio_)
pca_df=pd.DataFrame(pca_results, columns=['pca1', 'pca2', 'pca3'])
pca_df=pca_df.set_index(lfc.index)
# Out:
# [0.16968815 0.08489134 0.06650353]

# %%
lfc=lfc.merge(pca_df, left_index=True, right_index=True)

# %%
lfc
# Out:
#                                             Rv0003 Rv0004 Rv0007 Rv0008c  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -0.03  -3.81  -0.44   -0.22
# PPE68_KO_vs_mbio_H37Rv                       -0.08  -3.39  -0.14      -0
# Rv0950c_KO_vs_CB_WT                           0.03   -2.6  -0.47    0.43
# Rv0954_KO_vs_RJ_WT                            -1.2  -6.83  -1.21   -0.51
# Rv1096_KO_vs_CB_WT                            0.39   1.54  -0.34    0.58
# ...                                            ...    ...    ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5   0.41      0      0    0.15
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10    1.3      0   -0.9   -0.26
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  -0.49    0.7   3.05    0.44
# zhang_wt_mouse_d10_vs_zhang_input_library    -1.26  -2.62  -2.77    2.11
# zhang_wt_mouse_d45_vs_zhang_input_library    -2.25  -2.62  -7.24    0.59
#
#                                             Rv0009 Rv0010c Rv0011c Rv0012  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -0.13   -0.06    0.42  -0.24
# PPE68_KO_vs_mbio_H37Rv                       -0.12    0.07    0.56  -0.74
# Rv0950c_KO_vs_CB_WT                           -0.1    0.29    -1.6   0.29
# Rv0954_KO_vs_RJ_WT                            0.78    0.31   -6.75  -1.12
# Rv1096_KO_vs_CB_WT                            0.11    0.26   -1.98  -1.12
# ...                                            ...     ...     ...    ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  -0.24   -0.16       0   0.45
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10   0.26    0.09       0    1.3
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45   1.99    1.58       0  -0.17
# zhang_wt_mouse_d10_vs_zhang_input_library    -1.39    1.45    -3.5  -1.38
# zhang_wt_mouse_d45_vs_zhang_input_library     -4.1    0.46    -3.5  -2.21
#
#                                             Rv0016c Rv0017c  ... Rv3916c  \
# Dataset                                                      ...
# PE35_KO_vs_mbio_H37Rv                          0.09   -0.12  ...    0.55
# PPE68_KO_vs_mbio_H37Rv                        -0.25   -0.19  ...    1.11
# Rv0950c_KO_vs_CB_WT                           -0.96   -0.65  ...   -0.15
# Rv0954_KO_vs_RJ_WT                            -4.57   -3.85  ...    3.06
# Rv1096_KO_vs_CB_WT                            -0.84   -0.38  ...   -0.27
# ...                                             ...     ...  ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5    1.39   -1.39  ...    0.91
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10   -2.29    6.59  ...   -8.39
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45    2.39    1.99  ...    0.52
# zhang_wt_mouse_d10_vs_zhang_input_library     -3.08    -8.4  ...     2.1
# zhang_wt_mouse_d45_vs_zhang_input_library     -5.93   -4.38  ...   -4.66
#
#                                             Rv3919c Rv3920c Rv3921c Rv3922c  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                          0.01    0.06    1.98   -0.88
# PPE68_KO_vs_mbio_H37Rv                         0.29       0    1.92   -0.37
# Rv0950c_KO_vs_CB_WT                            0.63    0.26    0.25   -0.12
# Rv0954_KO_vs_RJ_WT                            -1.56   -1.73    0.16   -0.82
# Rv1096_KO_vs_CB_WT                             0.52   -0.05    0.87    0.47
# ...                                             ...     ...     ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5    0.73     1.7       0   -0.76
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10    0.54    2.99       0    1.65
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45   -1.56    0.75       0   -0.93
# zhang_wt_mouse_d10_vs_zhang_input_library     -1.02   -7.54       0   -2.15
# zhang_wt_mouse_d45_vs_zhang_input_library     -3.47   -5.43       0   -2.06
#
#                                             Rv3923c Rv3924c       pca1  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                         -0.32       0  -4.760095
# PPE68_KO_vs_mbio_H37Rv                          0.1       0  -4.325169
# Rv0950c_KO_vs_CB_WT                           -1.75       0  -9.116154
# Rv0954_KO_vs_RJ_WT                             3.01       0 -11.774741
# Rv1096_KO_vs_CB_WT                             0.28       0  -8.635184
# ...                                             ...     ...        ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5       0       0  -6.047181
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10       0       0 -10.719093
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45     1.6       0  -0.084878
# zhang_wt_mouse_d10_vs_zhang_input_library      -3.8       0  -5.052324
# zhang_wt_mouse_d45_vs_zhang_input_library      -3.8       0 -24.363793
#
#                                                   pca2       pca3
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -2.369996  -1.630707
# PPE68_KO_vs_mbio_H37Rv                       -2.313324  -1.223063
# Rv0950c_KO_vs_CB_WT                           0.404866  -1.930261
# Rv0954_KO_vs_RJ_WT                            4.011509  -6.554429
# Rv1096_KO_vs_CB_WT                           -2.633574   0.812886
# ...                                                ...        ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  -8.812395   1.011661
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10 -32.728199  12.076852
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45 -16.324142   5.275078
# zhang_wt_mouse_d10_vs_zhang_input_library    52.495823 -13.671348
# zhang_wt_mouse_d45_vs_zhang_input_library    68.171174 -14.172895
#
# [64 rows x 3514 columns]

# %%
(ggplot(lfc, aes(x='pca1', y='pca2')) 
 + geom_point() 
 + theme_light() 
 + geom_label(label=lfc.index, size=5, nudge_x=10)
 + xlab(f'pca1 {np.round(explained_var[0], 2)}') 
 + ylab(f'pca2 {np.round(explained_var[1], 2)}')
)
# Out:
# <ggplot: (8777359062513)>

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2).fit_transform(lfc[value_cols])

# %%
tsne = pd.DataFrame(tsne, columns=['tsne1', 'tsne2'])
tsne.index=lfc.index

# %%
lfc=lfc.merge(tsne, left_index=True, right_index=True)

# %%
(ggplot(lfc, aes(x='tsne1', y='tsne2'))+geom_point()+theme_light())
# Out:
# <ggplot: (8777354526113)>

# %%
lfc.columns.name = None

# %%
import scipy.cluster.hierarchy as shc
# shc.set_link_color_palette(['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666'])
shc.set_link_color_palette(['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628','#f781bf'])
import matplotlib.pyplot as plt
Z = shc.linkage(lfc[value_cols], method='ward', optimal_ordering=True)

# %%
print(lfc[value_cols].shape, Z.shape)
# Out:
# (64, 3511) (63, 4)

# %%
fig = plt.figure(figsize=(8, 14))
ax = fig.add_subplot(1, 1, 1)
shc.dendrogram(Z,  color_threshold=150,labels=lfc.index, orientation='left', above_threshold_color='grey')
ax.tick_params(axis='x', which='major', labelsize=11)
ax.tick_params(axis='y', which='major', labelsize=10.5)
plt.axvline(x=150, c='grey', lw=2, linestyle='dashed')
fig.savefig('dataset_dendrogram.jpg', bbox_inches = 'tight', dpi=500)

# %%
from sklearn.cluster import AgglomerativeClustering 
hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage ='ward')
y_hc=hc.fit_predict(lfc[value_cols])

# %%
lfc['y_hc']=y_hc

# %%
lfc
# Out:
#                                             Rv0003 Rv0004 Rv0007 Rv0008c  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -0.03  -3.81  -0.44   -0.22
# PPE68_KO_vs_mbio_H37Rv                       -0.08  -3.39  -0.14      -0
# Rv0950c_KO_vs_CB_WT                           0.03   -2.6  -0.47    0.43
# Rv0954_KO_vs_RJ_WT                            -1.2  -6.83  -1.21   -0.51
# Rv1096_KO_vs_CB_WT                            0.39   1.54  -0.34    0.58
# ...                                            ...    ...    ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5   0.41      0      0    0.15
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10    1.3      0   -0.9   -0.26
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  -0.49    0.7   3.05    0.44
# zhang_wt_mouse_d10_vs_zhang_input_library    -1.26  -2.62  -2.77    2.11
# zhang_wt_mouse_d45_vs_zhang_input_library    -2.25  -2.62  -7.24    0.59
#
#                                             Rv0009 Rv0010c Rv0011c Rv0012  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -0.13   -0.06    0.42  -0.24
# PPE68_KO_vs_mbio_H37Rv                       -0.12    0.07    0.56  -0.74
# Rv0950c_KO_vs_CB_WT                           -0.1    0.29    -1.6   0.29
# Rv0954_KO_vs_RJ_WT                            0.78    0.31   -6.75  -1.12
# Rv1096_KO_vs_CB_WT                            0.11    0.26   -1.98  -1.12
# ...                                            ...     ...     ...    ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  -0.24   -0.16       0   0.45
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10   0.26    0.09       0    1.3
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45   1.99    1.58       0  -0.17
# zhang_wt_mouse_d10_vs_zhang_input_library    -1.39    1.45    -3.5  -1.38
# zhang_wt_mouse_d45_vs_zhang_input_library     -4.1    0.46    -3.5  -2.21
#
#                                             Rv0016c Rv0017c  ... Rv3921c  \
# Dataset                                                      ...
# PE35_KO_vs_mbio_H37Rv                          0.09   -0.12  ...    1.98
# PPE68_KO_vs_mbio_H37Rv                        -0.25   -0.19  ...    1.92
# Rv0950c_KO_vs_CB_WT                           -0.96   -0.65  ...    0.25
# Rv0954_KO_vs_RJ_WT                            -4.57   -3.85  ...    0.16
# Rv1096_KO_vs_CB_WT                            -0.84   -0.38  ...    0.87
# ...                                             ...     ...  ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5    1.39   -1.39  ...       0
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10   -2.29    6.59  ...       0
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45    2.39    1.99  ...       0
# zhang_wt_mouse_d10_vs_zhang_input_library     -3.08    -8.4  ...       0
# zhang_wt_mouse_d45_vs_zhang_input_library     -5.93   -4.38  ...       0
#
#                                             Rv3922c Rv3923c Rv3924c  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                         -0.88   -0.32       0
# PPE68_KO_vs_mbio_H37Rv                        -0.37     0.1       0
# Rv0950c_KO_vs_CB_WT                           -0.12   -1.75       0
# Rv0954_KO_vs_RJ_WT                            -0.82    3.01       0
# Rv1096_KO_vs_CB_WT                             0.47    0.28       0
# ...                                             ...     ...     ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5   -0.76       0       0
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10    1.65       0       0
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45   -0.93     1.6       0
# zhang_wt_mouse_d10_vs_zhang_input_library     -2.15    -3.8       0
# zhang_wt_mouse_d45_vs_zhang_input_library     -2.06    -3.8       0
#
#                                                   pca1       pca2       pca3  \
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -4.760095  -2.369996  -1.630707
# PPE68_KO_vs_mbio_H37Rv                       -4.325169  -2.313324  -1.223063
# Rv0950c_KO_vs_CB_WT                          -9.116154   0.404866  -1.930261
# Rv0954_KO_vs_RJ_WT                          -11.774741   4.011509  -6.554429
# Rv1096_KO_vs_CB_WT                           -8.635184  -2.633574   0.812886
# ...                                                ...        ...        ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  -6.047181  -8.812395   1.011661
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10 -10.719093 -32.728199  12.076852
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  -0.084878 -16.324142   5.275078
# zhang_wt_mouse_d10_vs_zhang_input_library    -5.052324  52.495823 -13.671348
# zhang_wt_mouse_d45_vs_zhang_input_library   -24.363793  68.171174 -14.172895
#
#                                                   tsne1       tsne2 y_hc
# Dataset
# PE35_KO_vs_mbio_H37Rv                        -18.546289   25.069319    1
# PPE68_KO_vs_mbio_H37Rv                       -34.587902   12.047621    1
# Rv0950c_KO_vs_CB_WT                          -11.813895    3.492279    1
# Rv0954_KO_vs_RJ_WT                          -139.580765   -5.831884    1
# Rv1096_KO_vs_CB_WT                           -12.126139  -27.120695    1
# ...                                                 ...         ...  ...
# zhang_Tyloxapol_pH_6.5_vs_zhang_pcit_pH_4.5  -51.803810   67.932877    1
# zhang_mhcii_mouse_d10_vs_zhang_wt_mouse_d10   48.694798 -135.474182    1
# zhang_mhcii_mouse_d45_vs_zhang_wt_mouse_d45  -53.387859 -128.890701    1
# zhang_wt_mouse_d10_vs_zhang_input_library     61.554768   43.304394    1
# zhang_wt_mouse_d45_vs_zhang_input_library    -26.773949   99.148041    1
#
# [64 rows x 3517 columns]
