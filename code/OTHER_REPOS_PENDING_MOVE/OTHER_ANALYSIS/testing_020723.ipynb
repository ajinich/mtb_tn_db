# %%
import pandas as pd
import os

# %% [markdown]
# ## What is the difference between SI files and results (standardized) files?

# %% [markdown]
# ### Standardized datasets:

# %%
path_std = '../../data/standardized_data/'
[f for f in os.listdir(path_std) if '.csv' in f and 'result_logfc' in f]
# Out:
# ['result_logfc_matrix_2021_11_15_BASIS_mbio.csv',
#  'result_logfc_matrix_2021_05_18.csv',
#  'result_logfc_matrix_2021_08_27_BASIS.csv',
#  'result_logfc_matrix_2020_08_09.csv',
#  'result_logfc_matrix_2019_12_10.csv',
#  'result_logfc_matrix_2021_10_22.csv',
#  'result_logfc_matrix_2021_11_15_BASIS_invitro.csv',
#  'result_logfc_matrix_2020_06_27.csv',
#  'result_logfc_matrix_2021_11_15_BASIS_mbio_invitro.csv',
#  'result_logfc_matrix_2021_08_27.csv',
#  'result_logfc_matrix_2021_10_22_BASIS.csv',
#  'result_logfc_matrix_2020_08_27.csv']

# %%
fn_std = os.path.join(path_std, 'result_logfc_matrix_2021_11_15_BASIS_mbio.csv')
df_std = pd.read_csv(fn_std)
df_std.head(3)
# Out:
#     Rv_ID  PE35_KO_vs_mbio_H37Rv  PPE68_KO_vs_mbio_H37Rv  Rv0950c_KO_vs_CB_WT  \
# 0  Rv0001                  -0.41                    0.01                 0.00
# 1  Rv0002                   3.28                    2.38                 0.00
# 2  Rv0003                  -0.03                   -0.08                 0.03
#
#    Rv0954_KO_vs_RJ_WT  Rv1096_KO_vs_CB_WT  \
# 0                 0.0                0.00
# 1                 0.0                0.00
# 2                -1.2                0.39
#
#    Rv3005c_KO_day32_vs_dejesus_H37Rv_day32  Rv3594_KO_vs_Rubin_FLUTE_WT  \
# 0                                     3.12                        -0.06
# 1                                     0.00                         0.00
# 2                                     3.83                         0.31
#
#    Rv3684_KO_vs_CB_WT  Rv3717_KO_vs_Rubin_FLUTE_WT  ...  \
# 0                0.00                        -0.06  ...
# 1                0.00                         0.00  ...
# ...

# %%
print(df_std.shape)
df_std.columns[:50]
# Out:
# (4055, 126)
# Index(['Rv_ID', 'PE35_KO_vs_mbio_H37Rv', 'PPE68_KO_vs_mbio_H37Rv',
#        'Rv0950c_KO_vs_CB_WT', 'Rv0954_KO_vs_RJ_WT', 'Rv1096_KO_vs_CB_WT',
#        'Rv3005c_KO_day32_vs_dejesus_H37Rv_day32',
#        'Rv3594_KO_vs_Rubin_FLUTE_WT', 'Rv3684_KO_vs_CB_WT',
#        'Rv3717_KO_vs_Rubin_FLUTE_WT', 'Rv3811_KO_vs_Rubin_FLUTE_WT',
#        'bellerose_MB_HRZE_wk1_vs_bellerose_MB_d21_untreated',
#        'bellerose_MB_HRZE_wk1_vs_bellerose_MB_pretreatment',
#        'bellerose_MB_d21_untreated_vs_bellerose_MB_pretreatment',
#        'carey_621_vs_carey_rv', 'carey_630_vs_carey_rv',
#        'carey_631_vs_carey_rv', 'carey_632_vs_carey_rv',
#        'carey_641_vs_carey_rv', 'carey_662_vs_carey_rv',
#        'carey_663_vs_carey_rv', 'carey_667_vs_carey_rv',
#        'dejesus_H37Rv_day32_vs_dejesus_H37Rv_day0',
#        'dejesus_Rv0307c_day32_vs_dejesus_Rv0307c_day0',
#        'dejesus_Rv1432_day0_vs_dejesus_H37Rv_day0',
#        'dejesus_Rv1432_day32_vs_dejesus_H37Rv_day32',
# ...

# %% [markdown]
# ### SI datasets:

# %%
path_SI = '../../data/SI_datasets/'
[f for f in os.listdir(path_SI) if '.csv' in f and 'SI' in f]
# Out:
# ['SI_qval.csv',
#  'SI_bin.csv',
#  'SI_qval_bxd.csv',
#  'SI_log2FC_bxd.csv',
#  'SI_log2FC.csv']

# %%
fn_SI = os.path.join(path_SI, 'SI_log2FC.csv')
df_SI = pd.read_csv(fn_SI)
df_SI.head(3)
# Out:
#     Rv_ID gene_name  2003A_Sassetti  2003B_Sassetti  2005_Rengarajan  \
# 0  Rv0001      dnaA       -3.378401             NaN              NaN
# 1  Rv0002      dnaN             NaN             NaN              NaN
# 2  Rv0003      recF             NaN             NaN              NaN
#
#    2006_Joshi_GI_1  2006_Joshi_GI_2  2011_Griffin_2  2013_Zhang_1A  \
# 0              NaN              NaN             NaN            NaN
# 1              NaN              NaN             NaN            NaN
# 2              NaN              NaN             NaN      -6.211402
#
#    2013_Zhang_1B  ...  2018_Carey_1B  2018_Carey_1C  2018_Carey_1D  \
# 0            NaN  ...           0.00          -0.05           4.53
# 1            NaN  ...           0.00           0.00           0.00
# 2      -3.223423  ...           0.03          -0.64          -0.49
#
#    2018_Carey_1E  2018_Carey_1F  2018_Carey_1G  2018_Carey_1H  \
# 0           0.00           0.00           2.14            0.0
# ...

# %%
print(df_SI.shape)
df_SI.columns[:50]
# Out:
# (3990, 42)
# Index(['Rv_ID', 'gene_name', '2003A_Sassetti', '2003B_Sassetti',
#        '2005_Rengarajan', '2006_Joshi_GI_1', '2006_Joshi_GI_2',
#        '2011_Griffin_2', '2013_Zhang_1A', '2013_Zhang_1B', '2013_Zhang_2',
#        '2013_Zhang_3A', '2013_Zhang_3B', '2013_Zhang_3C', '2013_Zhang_3D',
#        '2016_Korte', '2018_Rittershaus_1A', '2018_Rittershaus_1B',
#        '2012_Zhang', '2015_Kieser_GI_1', '2015_Kieser_GI_2',
#        '2015_Kieser_GI_3', '2015_Mendum', '2016_Nambi', '2017_Mishra_1',
#        '2017_Mishra_2', '2017_Xu_1A', '2017_Xu_1B', '2017_Xu_1C', '2017_Xu_1D',
#        '2017_Xu_1E', '2018_Carey_1A', '2018_Carey_1B', '2018_Carey_1C',
#        '2018_Carey_1D', '2018_Carey_1E', '2018_Carey_1F', '2018_Carey_1G',
#        '2018_Carey_1H', '2017B_DeJesus_1A', '2017B_DeJesus_1B',
#        '2017B_DeJesus_1C'],
#       dtype='object')
